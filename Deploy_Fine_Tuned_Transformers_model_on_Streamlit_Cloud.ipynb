# %% [markdown]
# #### Deploy Finetuned transformers (BERT) model
#
# * Push model to huggingface hub
# * Deploy it on streamlit cloud

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 42.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 9.2 MB/s eta 0:00:00
# ...

# %%
# !pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification

# %%
from google.colab import drive
drive.mount('/content/drive')
model = BertForSequenceClassification.from_pretrained("/content/drive/MyDrive/BERT Model on Custom Dataset")
# model.to('cuda')
model

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
model.push_to_hub("Yassershrief/toxic-TuneBert")
# Out:
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/Yassershrief/toxic-TuneBert/commit/d725e7f0a329f42434853ccdb476f642234bc7c4', commit_message='Upload BertForSequenceClassification', commit_description='', oid='d725e7f0a329f42434853ccdb476f642234bc7c4', pr_url=None, pr_revision=None, pr_num=None)
